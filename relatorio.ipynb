# %% [markdown]
#                                             Relatório do Sistema de Estoque

# %% [markdown]
#         Objetivo

# %% [markdown]
# Criar um sistema simples para controlar produtos em estoque usando Laravel/Laragon, PHP 8.2 e SQLite.

# %% [markdown]
#         Visão Geral

# %% [markdown]
# Foi desenvolvido um sistema de controle de estoque utilizando PHP, Laravel e SQLite.

# %% [markdown]
# O sistema permite:

# %% [markdown]
# Cadastro de produtos

# %% [markdown]
# Edição de produtos
#
#  Exclusão de produtos
#
#  Cadastro de categorias
#
#  Consulta de estoque* Dashboard com indicadores
#
#  Busca por nome ou código

# %% [markdown]
#          Arquitetura

# %% [markdown]
# Padrão utilizado:
#
#
#
#
# MVC (Model View Controller)

# %% [markdown]
#         Estrutura

# %% [markdown]
# app/
# ├── Models
#    ├─ Produto.php
# │   └─ Categoria.php
#
#
#
#
#
#
#
# app/
#
# ├─ Http/Controllers
# │   ├─ ProdutoController.php
# │   └── DashboardController.php
#
#
#
#
#
#
#
#
# resources/views
# ├─ dashboard.blade.php
#
# └─ produtos
#      ├─ index.blade.php
#     ├─ create.blade.php
#    └─ edit.blade.php

# %% [markdown]
# Banco de Dados
#
# Banco utilizado:
#
# SQLite

# %% [markdown]
# Arquivo físico:
#
# database/database.sqlite
#
#
#
#
# Configuração encontrada:
#
#
#
#                 env
#
# DB_CONNECTION=sqlite

# %% [markdown]
#
# Relatório de teste de Software
#
#
#
#
#
#
#
#
#
#
#      Projeto
#
# Sistema de Controle de Estoque em Laravel

# %% [markdown]
#                     Objetivo dos Testes
#
# Verificar se o sistema está funcionando corretamente, se os dados estão sendo gravados no banco de dados e se as funcionalidades principais operam sem erros.
#
# Ambiente de Teste
#
#
#
#
#  PHP 8.2
#  Laravel
#  SQLite
#  Windows
#  VS Code
#  PowerShell

# %% [markdown]
# Casos de Teste Executados
#
#  Cadastro de Produto
#
# Teste: Cadastrar novos produtos.
#
# Resultado: Aprovado
#
# Produtos cadastrados com sucesso no banco de dados.

# %% [markdown]
#                         Edição de Produto
#
# Teste: Alterar informações de produtos existentes.
#
# Resultado: Aprovado
#
# As alterações foram gravadas corretamente.

# %% [markdown]
#                     Exclusão de Produto
#
# Teste: Remover produtos do sistema.
#
# Resultado: Aprovado
#
# Os registros foram removidos corretamente.

# %% [markdown]
#                     Busca por Nome
#
# Teste: Pesquisar produtos pelo nome.
#
# Resultado: Aprovado
#
# O sistema retornou os produtos encontrados.
#
#  Busca por Código
#
# Teste: Pesquisar produtos pelo código.

# %% [markdown]
#                     Resultado: Aprovado
#
# O sistema retornou os registros corretos.

# %% [markdown]
#                     Relacionamento Produto x Categoria
#
# Teste: Verificar se cada produto pertence a uma categoria.
#
#                     Resultado: Aprovado
#
# Relacionamento funcionando corretamente.
#
#  Banco de Dados
#
#                     Teste: Verificar persistência dos dados.
#
# Resultado: Aprovado
#
# Dados armazenados corretamente no SQLite.

# %% [markdown]
#                 Rotas do Sistema
#
# Teste: Executar:
#
#
# php artisan route:list
#
# Resultado: Aprovado
#
# 16 rotas registradas sem falhas.
#
#  Estrutura do Banco
#
# Teste: Verificar migrations.

# %% [markdown]
#                     Resultado: Aprovado
# Todas as migrations executadas com sucesso.
#
#
#                     Sintaxe do Código
#
#
# php -l app\Http\Controllers\ProdutoController.php
#
#
#                     Resultado: Aprovado
# Nenhum erro de sintaxe encontrado.
#
#     Evidências Encontradas
#
#                      Categorias
#
#                     Foram encontradas 4 categorias:
#
#  Material de Limpeza
#  Material Tecnológico
#  Material de Escritório
#  Outros

# %% [markdown]
#                 Produtos
#
# Foram encontrados 25 produtos cadastrados.
#
# Exemplos:
#
#  Papel A4
#  Caneta Azul
#  Computador
#  Notebook
#  Monitor
#  Água Sanitária
#  Sabão em Pó
#  Cadeira
#  Caixa de Papelão
#
#
#
#          Não Conformidades Encontradas
#
#  Problema de Codificação de Caracteres
#
# Ocorrência identificada durante os testes:
#
#
#         Material Tecnol?gico
# Material de Escrit?rio
#
#
#         Status: Corrigido
#
#
#         Aviso de Inicialização
#
#                 Mensagem encontrada:
#
#
# Warning: Module "pdo_sqlite" is already loaded
#
#
#         Impacto: Baixo
#
# Status: Não impede a execução do sistema.
#
#  Resultado Final
#
# | Item Testado    | Status |
# | -----     ----- | --  -- |
# | Cadastro        | v      |
# | Edição          | v     |
# | Exclusão        | v      |
# | Busca           | v      |
# | Banco SQLite    | v      |
# | Rotas           | v      |
# | Relacionamentos | v      |
# | Migrations      | v      |
# | Sintaxe PHP     | v      |
#
#
#                                         Conclusão
#
# Após os testes realizados, o sistema apresentou funcionamento adequado para as funcionalidades principais. Os dados estão sendo persistidos corretamente no banco SQLite, as rotas estão registradas, os relacionamentos entre produtos e categorias funcionam corretamente e não foram encontrados erros críticos que impeçam a utilização do sistema.
#
#     Resultado Geral: APROVADO
#
#     Cobertura manual executada: Cadastro, consulta, edição, exclusão, busca, relacionamento e persistência de dados.
#     Nível de qualidade atual: Júnior/Pleno, apto para demonstração acadêmica e evolução para ambiente corporativo.
